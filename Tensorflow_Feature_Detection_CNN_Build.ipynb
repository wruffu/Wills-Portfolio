# %% [markdown]
# # Keras CNN Padding, Stride, Pooling, Activation

# %% [markdown]
# It's challenging to develop an intuition of how the shape of the kernel and other related configuration parameters of a Convolution layer will affect the shape of the output.
#
# In CNN, having a concrete understanding of the size of the output of each layer is necessary. Hence, in this notebook, we will dive into some of the important factors to consider when working with CNNs, namely, Padding, Stride, Pooling, and Activation.

# %% [markdown]
# ## Table of Contents
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Padding and Stride">Padding and Stride</a>
#         <ol>
#             <li><a href="#Background">Background</a></li>
#             <li><a href="#How-does-Padding-work?">How does Padding work?</a></li>
#             <li><a href="#Using Padding in Tensorflow.keras">Using Padding in Tensorflow.keras</a></li>
#             <li><a href="#How-does-Stride-work?">How does Stride work?</a>
#             <li><a href="#Example 1: Image Processing - Edge Detection">Example 1: Image Processing - Edge Detection</a></li>
#         </ol>
#     </li>
#     <li><a href="Activation">Activation</a>
#         <ol>
#             <li><a href="#Example 2: Feature Detection with Kernel and Activation">Example 2: Feature Detection with Kernel and Activation</a></li>
#         </ol>
#     </li>
#     <li><a href="Pooling">Pooling</a>
#         <ol>
#             <li><a href="#What is Pooling?">What is Pooling?</a></li>
#             <li><a href="#Example 3: Max or Average?">Example 3: Max or Average?</a></li>
#         </ol>
#     </li>
#     <li><a href="#Exercises">Exercises</a>
#         <ol>
#             <li><a href="#Exercise 1 - Display some images">Exercise 1 - Display some images</a></li>
#             <li><a href="#Exercise 2 - Set up a Convolution layer">Exercise 2 - Set up a Convolution layer</a></li>
#             <li><a href="#Exercise 3 - Set up a Max Pooling layer">Exercise 3 - Set up a Max Pooling layer</a></li>
#             <li><a href="#Exercise 4 - Create a deeper CNN with blocks">Exercise 4 - Create a deeper CNN with blocks</a></li>
#             <li><a href="#Optional section">Optional section</a></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# ## Concepts covered:
#
#  - The use of padding and stride in CNN
#  - Calculating the size of the output of a layer
#  - The necessity of activations
#  - The difference between Max Pooling and Average Pooling

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# General Libraries used:
# >
#     tensorflow
#     pandas
#     numpy
#     sklearn
#     seaborn
#     matplotlib

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install -qy numpy==1.22.3 matplotlib==3.5.1 tensorflow==2.9.0 opencv-python==4.5.5.62

# RESTART KERNEL AFTERWARD LIBRARIES ARE INSTALLED

# %%
# %pip install -qy tqdm

# %%
# %pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.6.0)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.9.2)
# Requirement already satisfied: namex in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\willl\onedrive\desktop\my_documents\wills_py_folder\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.0
#     Uninstalling numpy-2.1.0:
#       Successfully uninstalled numpy-2.1.0
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   c:\Users\willl\OneDrive\Desktop\My_Documents\Wills_Py_Folder\venv\Scripts\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   c:\Users\willl\OneDrive\Desktop\My_Documents\Wills_Py_Folder\venv\Scripts\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   c:\Users\willl\OneDrive\Desktop\My_Documents\Wills_Py_Folder\venv\Scripts\python.exe -m pip install [options] [-e] <vcs project url> ...
#   c:\Users\willl\OneDrive\Desktop\My_Documents\Wills_Py_Folder\venv\Scripts\python.exe -m pip install [options] [-e] <local project path> ...
#   c:\Users\willl\OneDrive\Desktop\My_Documents\Wills_Py_Folder\venv\Scripts\python.exe -m pip install [options] <archive url/path> ...
#
# no such option: -y

# %% [markdown]
# ### Importing Required Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_digits, load_wine

import pathlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import PIL
from PIL import Image, ImageOps
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, datasets
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D

sns.set_context('notebook')
sns.set_style('white')

# %% [markdown]
# ### Defining Helper Functions

# %% [markdown]
# The Sobel operator for edge detection **v_grad** and **h_grad** will be defined later.

# %%
# This function will allow us to easily plot data taking in x values, y values, and a title
def sobel(img, strides, padding, activation=None):

    input_layer = layers.Input(shape=(img_height, img_width, 1))

    v_conv = layers.Conv2D(filters=1,
                       kernel_size=3,
                       kernel_initializer=v_grad,
                       strides=strides,
                       padding=padding,
                       activation=None)
    h_conv = layers.Conv2D(filters=1,
                   kernel_size=3,
                   kernel_initializer=h_grad,
                   strides=strides,
                   padding=padding,
                   activation=None)

    v_model = keras.Sequential([input_layer, v_conv])
    h_model = keras.Sequential([input_layer, h_conv])

    out_d = h_model.output_shape[1:]        # removed layers.output_shape from original.
    Gx = h_model.predict(img).reshape(out_d)
    Gy = v_model.predict(img).reshape(out_d)
    G = np.sqrt(np.add(np.multiply(Gx, Gx), np.multiply(Gy, Gy)))

    return G

# %% [markdown]
# ## Padding and Stride

# %% [markdown]
# ### Background

# %% [markdown]
# In our previous notebook where we introduced image convolutions, we mentioned that we tend to lose the pixels on the border of our input image because there are not enough pixels surrounding them to support the kernel matrix multiplications. This could be detrimental to our CNN model performance since we will increasingly lose information as we apply many successive convolution layers.
#
# To avoid losing important information carried by border pixels and control the size of our convolution output at the same time, one solution would be to use **Padding** and **Stride** when shifting a kernel on the input image.

# %% [markdown]
# ### How does Padding work?
#
# Padding essentially extends the perimeter of our image by adding extra pixels, commonly **zero-valued**, on the outer frame of the image. This is done so that the border pixels could also be at or near the center of the receptive field when the kernel window slides through, and the information is retained as useful features for the next step.
#
# The following figure illustrates the case where we apply a $3\times3$ kernel on a $3\times3$ image array with 2 rows of padding (1 on top, 1 on bottom) and 2 columns of padding (1 on left, 1 on right):
#
# <center><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/images/pad1_blue_.jpg" width="50%"></center>
#
# As the kernel window slides through the padded image, we will obtain an output image with the same size as the input, which is $3\times3$.

# %% [markdown]
# In general, if we add a total of $p_r$ rows of padding and $p_c$ columns of padding to a $m\times n$ input, the output shape after applying a $k\times k$ kernel will be:
#
# $$(m+p_r-k+1)\times (n+p_c-k+1)$$
#
# This formula implies that if we want the size of input and output to be the same, we need to make sure that $p_r=k-1=p_c$. As we would pad on the left and right, top and bottom of an image, $p_r$ and $p_c$ are typically even numbers so that all the previous layer pixels would be symmetrical around the outout pixel. This is why we tend to choose odd kernel sizes, such as $3\times3$, $5\times5$, etc.

# %% [markdown]
# ### Use Padding in Tensorflow.Keras
#
# In Keras, the operation of padding is specified via the `padding` argument in `keras.layers.Conv2D`. The default is `padding = 'valid'`, which means no padding. Setting `padding = 'same'` will calculate the required padding size such that the input and output will have the same shape and also add the padding, given an input and a kernel size.
#
# The example below adds padding to a convolutional layer:

# %%
from keras.models import Sequential
from keras.layers import Conv2D

model = Sequential()
model.add(Conv2D(filters = 1,
                 kernel_size = (3,3),
                 padding = 'same',
                 input_shape = (10, 10, 1)))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 10, 10, 1)      │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10 (40.00 B)
#  Trainable params: 10 (40.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# So we built a simple CNN model with one convolution layer, where we specified an input shape of $10\times10$ with one channel and the kernel applied is $3\times3$. Via padding, the output shape is also $10\times10$!

# %% [markdown]
# ### How does Stride work?

# %% [markdown]
# In the previous example, we defaulted to shifting the kernel window one pixel at a time across the image left to right, top to bottom. However, sometimes for computational efficiency or because we simply wish to downsample, we could choose to move the kernel window more than one pixel at a time.
#
# The number of rows and columns traversed per slide is referred to as the **Stride**. In Keras, we could specify the stride in `keras.layers.Conv2D` via the `strides` argument, as a tuple of 2 integers. For example, `strides = (2,3)` means we shift the kernel 2 pixels right for each horizontal movement and 3 pixels down for each vertical movement.
#
# **Combining the concept of Padding and Stride**, if we add a total of $p_r$ rows of padding and $p_c$ columns of padding to a $m\times n$ input, the output shape after applying a $k\times k$ kernel with $(s_r, s_c)$ stride will be:
#
# $$[(m+p_r-k) / s_r+1]\times [(n+p_c-k) / s_c+1]$$
#
#
# To illustrate, the full convolution process using one $3\times3$ kernel on a $3\times3$ input image with padding in place and `strides = (2,2)` looks like:
#
# <center><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/images/paddingstride.gif" width="85%"></center>
#
# We can code this in Keras:

# %%
model = Sequential()
model.add(Conv2D(filters = 1,
                 kernel_size = (3, 3),
                 strides = (2, 2),
                 padding = "same",
                 input_shape = (3, 3, 1)))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 2, 2, 1)        │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10 (40.00 B)
#  Trainable params: 10 (40.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# So the output shape calculated by Keras is indeed $2\times2\times1$, where the one indicates the output channel (because we only applied one kernel).
#
# We can code the input image array and the $3\times3$ kernel, and then use a simple CNN with one **Conv2D** layer to predict the output values.
#
# **NOTE:** Before feeding the input into the CNN, we need to reshape it so that the first **1** represents the batch size and the last **1** represents the number of channels the input contains.

# %%
input_ = np.array([[1, 1, 3],
              [2, 1, 2],
              [3, 1, 4]]).reshape(1, 3, 3, 1)

kernel = np.array([[1, 0, -1],
                   [1, 0, -1],
                   [1, 0, -1]]).reshape(3, 3, 1, 1) # reshaping the kernel is important

b = np.array([0.0])

model.set_weights([kernel, b])
output_ = model.predict(input_)

for r in range(output_.shape[1]):
    print([output_[0,r,c,0] for c in range(output_.shape[2])])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [-2.0, 2.0]
# [-2.0, 2.0]

# %% [markdown]
# **With the same input and kernel, the output matrix of our CNN is the same as the one shown in the animated gif.**

# %% [markdown]
# ### Edge Detection Example: Image Processing
#
# In a previous image convolution notebook, we reviewed the Sobel Operator which uses two kernels to convolve with an image to perform edge detection. In this example, we will use the Sobel Operator to detect edges in the image of the [Leaning Tower of Pisa](https://pxhere.com/en/photo/1027167) with padding and stride.

# %% [markdown]
# Let's first define the two kernels used for the [Sobel Operator](https://en.wikipedia.org/wiki/Sobel_operatorhttps://en.wikipedia.org/wiki/Sobel_operator):

# %%
# Lets define our custom kernels for the horizontal and vertical gradients
def v_grad(shape, dtype=None):
    # Here we use a single numpy array to define our x gradient kernel
    grad = np.array([
        [1, 0, -1],
        [2, 0, -2],
        [1, 0, -1]
    ]).reshape((3, 3, 1, 1))
    # this line is quite important, we are saying we want one 3x3 kernel each for one channel of pixels (grayscale)

    # We check to make sure the shape of our kernel is the correct shape
    # according to the initialization of the Convolutional layer below
    assert grad.shape == shape
    return keras.backend.variable(grad, dtype='float32')

def h_grad(shape, dtype=None):
    grad = np.array([
        [1, 2, 1],
        [0, 0, 0],
        [-1, -2, -1]
        ]).reshape((3, 3, 1, 1))

    assert grad.shape == shape
    return keras.backend.variable(grad, dtype='float32')

# %% [markdown]
# Lets download this cloud storage object of the Leaning Tower of Pisa and view it.

# %%
import requests

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/images/pisa.jpg"
filename = "pisa.jpg"

response = requests.get(url)
with open(filename, 'wb') as file:
    file.write(response.content)

# %%
img_width = 350
img_height = 500
img = PIL.Image.open("pisa.jpg").resize((img_width, img_height))
img
# Out:
# <PIL.Image.Image image mode=RGB size=350x500>

# %% [markdown]
# Next lets set `padding = 'same'` and try different values of `strides` for convolving the two kernels of the Sobel operator over the image. We will use the pre-defined function **sobel**.

# %%
input_img = ImageOps.grayscale(img)
input_img = np.array(input_img).reshape((1, img_height, img_width, 1))

fig, axs = plt.subplots(1, 3, figsize=(9, 10), constrained_layout=True)
fig.set_constrained_layout_pads(w_pad=0.01, h_pad=0.02, hspace=0, wspace=0.1)

for i, ax in enumerate(axs.flat):
    output = sobel(img = input_img,
                   padding='same',
                   strides=i+1).astype('int').clip(0,255)

    ax.imshow(output, cmap='gray')
    ax.set_title(f"Strides: {i+1}, Shape: {output.shape}", fontsize=13)
    ax.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000016BA11A4F40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000016BA12399E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %% [markdown]
# As we increase the value of `strides`, the output shape becomes proportionally smaller (as shown in the image titles) but edges detected also become blurry. Therefore, whether to use stride and what value to use will usually be dependent on the problem at hand.

# %% [markdown]
# ## Activation Explained

# %% [markdown]
# Recall in the previous example (or in the gif), the output matrix contains negative values such as -2. However, since CNN is typically implemented on images which should consist of pixels values ranging from 0 to 255, we need to make our CNN valid by adding what's called an activation after the convolution operation.
#
# In addition to the need of restricting certain limits for the values in our matrices, activations are also necessary for adding **non-linearity** into our network so that the network can learn complex patterns in the data.
#
# In `tensorflow.keras.layers.Conv2D`, there is the argument `activation` where we can specify the type of activation we want for the current convolution layer added. There are many types of activations existing, such as Sigmoid, Tanh, ReLU, etc. For example, the famous **Sigmoid** function is defined as follows:
#
# $$ f(x) =  \frac{\mathrm{1} }{\mathrm{1} + e^{-x}}  $$
#
# We can code the sigmoid function using numpy:

# %%
def sigmoid(X):

    return 1/(1 + np.exp(-X))

X = np.linspace(-10, 10, 100)
sigmoid_X = sigmoid(X)
plt.plot(X, sigmoid_X)
plt.axhline(y=0.5, color='r', linestyle='-')
plt.xlabel("x")
plt.ylabel("Sigmoid(x)")
# Out:
# Text(0, 0.5, 'Sigmoid(x)')

# %% [markdown]
# The sigmoid function is also called a **squashing function**. The input to the sigmoid activation is usually a weighted sum of the outputs of the previous layer. If the input is either a very large negative number or a very large positive number, the output of the activation is always between 0 and 1.
#
#
# Other than the sigmoid activation, there are different kinds of activation functions [seen here](https://en.wikipedia.org/wiki/Activation_function). We'll use the **ReLU** activation next.
#
# **ReLU** or **Rectified Linear Unit**, is a widely used activation function, especially with Convolutional Neural networks. It is defined as:
#
# $$f(x) = max(0, x)$$
#
# Where x is the matrix obtained after convolution. By using ReLU, we can filter out all the negative values as they will become zero's and just keep the positive values.
#
# We can also code the relu activation using numpy:

# %%
def relu(X):
    return np.maximum(0, X)

X = np.linspace(-10, 10, 100)
relu_X = relu(X)
plt.plot(X, relu_X)
plt.xlabel("x")
plt.ylabel("Relu(x)")
# Out:
# Text(0, 0.5, 'Relu(x)')

# %% [markdown]
# ### Kernel and Activation Example: Feature Detection
#
# In this example, instead of using the Sobel operator for edge detection, we will convolve a simple kernel over all three channels of a RGB image for the same purpose. This means our final result of edge detection will be color instead of a grayscale image.
#
# We'll use the following kernel:
#
# $$
# 	\begin{bmatrix}
# 	-1 & -1 & -1 \\\\\\
# 	-1 & 8 & -1\\\\
# 	-1 & -1 & -1\\\\
# 	\end{bmatrix}
# 	\quad
# $$
#
# Note that this kernel will be has some negative values, therefore we should specify an activation function (namely **ReLu**) in our Conv2D layer to filter out the negative values.

# %% [markdown]
# Download this cool Lamborghini image held as a cloud storage object.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/images/lambor.jpeg"
filename = "lambor.jpeg"
response = requests.get(url)
with open(filename, 'wb') as file:
    file.write(response.content)
# Will save to active notebook folder as a file.

# %%
img_width = 500
img_height = 280

img = Image.open("lambor.jpeg").resize((img_width, img_height))
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x280>

# %% [markdown]
# As we will be convolving the kernel over each channel, we need to split the RGB image into three channels or three grayscale images.
#
# Let's display the three channels:

# %%
arr = np.array(img)
red_c = arr[:,:,0]
green_c = arr[:,:,1]
blue_c = arr[:,:,2]

channels = [red_c, green_c, blue_c]
names = ["Red", "Green", "Blue"]

plt.figure(figsize=(18, 5))

for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(channels[i], cmap='gray')
    plt.axis("off")
    plt.title(f"{names[i]} channel", fontsize=13)

# %% [markdown]
# We see that the color of the car, as represented by color brightness, is mostly coming from the red and green channel, and very little from the blue channel.
#
# Now we build a simple CNN with one Conv2D layer, using the kernel specified above as the weights.

# %%
kernel = np.array([[-1,-1,-1],
                   [-1,8,-1],
                   [-1,-1,-1]]).reshape(3,3,1,1)
b = np.array([0.0])

model = keras.Sequential()
model.add(layers.Conv2D(input_shape = (img_height, img_width, 1),
                 filters=1,
                 kernel_size=3,
                 padding='same',
                 activation='relu'
                 ))
model.set_weights([kernel, b])
model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 280, 500, 1)    │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10 (40.00 B)
#  Trainable params: 10 (40.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Once we initialize our CNN, we can now use it to predict the edge detection result for each of the R, G, B channel's gray image.
#
# Don't worry if the predicted results look almost all-black. This is because we used ReLu activation to set all the negative pixel values to 0. In each channel, if the pixel value is 0, the pixel will appear black. Only the important information will be kept.

# %%
acts = []
plt.figure(figsize=(18,5))

for i in range(3):
    plt.subplot(1,3,i+1)

    # loop through each channel
    input_ = channels[i].reshape((1, img_height, img_width, 1))
    act = model.predict(input_).squeeze(0).squeeze(2).astype('int').clip(0,255)
    # store the result in a list called "acts"
    acts.append(act)

    plt.imshow(act, cmap='gray')
    plt.axis("off")
    plt.title(f"{names[i]} Channel with activation", fontsize=13)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# Now it's time to stack the three channels back together and see what our edge detection tool did for us!

# %%
arr_hat = np.dstack((acts[0],acts[1],acts[2]))

plt.figure(figsize=(10,5))
plt.imshow(arr_hat)
plt.axis("off")
# Out:
# (-0.5, 499.5, 279.5, -0.5)

# %% [markdown]
# Since we applied the edge detector on the three color channels separately, once we merge the results after the convolutions we obtain colorful edges of the car. Each colored edge that you see in the picture above is contributed by some degree of red edges detected in channel R, green edges detected in channel G, and blue edges in channel B.

# %% [markdown]
# ## Pooling

# %% [markdown]
# ### What is Pooling?
#
# A CNN model may include local and/or global pooling layers along with traditional convolutional layers. It is a form of non-linear down-sampling to progressively **reduce the spatial size of the representation**, to **reduce the number of parameters**, **memory footprint and amount of computation in the network**, and hence to also **control overfitting**.
#
# There are two common types of pooling in popular use: **Max Pooling** and **Average Pooling**. Max pooling outputs the maximum value of each sub-region in the feature map, while average pooling outputs the average value.
#
# It is common to periodically insert a pooling layer between successive convolutional layers (each one typically followed by an activation function, such as a ReLU layer) in a CNN architecture. You can read more about Pooling [here](https://en.wikipedia.org/wiki/Convolutional_neural_network#Pooling_layer).
#
# An illustration of **Max Pooling**:
#
# <center><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/images/maxpooling.gif" width="1100"></center>

# %% [markdown]
# In tensorflow.keras, a **Pooling layer** downsamples the input along its spatial dimensions (height and width) by taking the maximum or average value over an input window (of size defined by `pool_size`) for each channel of the input.
#
# You can add a Pooling layer to a CNN with **MaxPooling2D** or **AveragePooling2D**. Like a **Conv2D** layer, a Pooling layer also has arguments such as `padding` and `strides`, and they work in a same way as in a Conv2D layer.

# %% [markdown]
# ### Max or Average Pooling Example: What to use?
#
# - Max pooling **retains the most prominent features in the feature map**. It is useful when the background of the image is dark and we are interested in the lighter pixels of the image. For example, in the MNIST dataset, the digits are represented in white color and the background is black, so max pooling is more suitable.
#
# - Average pooling **tends to smooth out the image**. Sometimes it cannot extract the important features because it takes everything into account, and gives an average value which may or may not be important. It shows a similar effect irrespective of the background.

# %% [markdown]
# Run the next cell to download the MNIST datset, which we will use to illustrate the difference between the output of Max Pooling and Average Pooling.

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
print("MNIST downloaded!")
print("Train set shape:", X_train.shape)
# Out:
# MNIST downloaded!
# Train set shape: (60000, 28, 28)

# %% [markdown]
# Let's extract 5 random images from the train set and display them:

# %%
images = []
plt.figure(figsize=(15,3))
for i in range(5):
    img = X_train[np.random.randint(0, 60000)].astype('float')
    images.append(img)

    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')

# %% [markdown]
# Next lets use our **max_pool** and **avg_pool** tool to perform pooling on these five images and see how their results appear differently.

# %%
max_pool = keras.Sequential([MaxPooling2D(pool_size = (2,2))])
avg_pool = keras.Sequential([AveragePooling2D(pool_size = (2,2))])

fig1, axs1 = plt.subplots(1, 5, figsize=(12,3), constrained_layout=True)
fig2, axs2 = plt.subplots(1, 5, figsize=(12,3), constrained_layout=True)
fig1.suptitle("Max pooling result", fontsize=20)
fig2.suptitle("Average pooling result", fontsize=20)

for img, ax1, ax2 in zip(images, axs1.flat, axs2.flat):
    input_ = img.reshape(1, 28, 28, 1)
    ax1.imshow(max_pool.predict(input_).squeeze(0).squeeze(2))
    ax1.axis('off')
    ax2.imshow(avg_pool.predict(input_).squeeze(0).squeeze(2))
    ax2.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# As we can see, in max pooling the prominent features are highlighted more, whereas in average pooling it gives a smoother image retaining the complete features in the image.
#
# We cannot say that one particular pooling method is better than the other generally. The choice of pooling operation should be made based on the use dataset or business need.

# %% [markdown]
# ## Practice
#
# In this exercise, you will support building a CNN to classify images from the famous CIFAR10 dataset.
#
# The pre-defined **load_cifar10** function will return a preprocessed cifar10 dataset, where:
#
# 1. The pixel values in **X_train** and **X_test** are normalized float numbers.
# 2. The **y_train** and **y_test** are one-hot encoded into 10-element binary vectors with a 1 for the index of the class value.

# %%
from keras.utils import to_categorical
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from keras.models import Sequential

def load_cifar10():
    (trainX, trainY), (testX, testY) = datasets.cifar10.load_data()

    trainX = trainX.astype('float32') / 255
    testX = testX.astype('float32') / 255

    trainY = to_categorical(trainY)
    testY = to_categorical(testY)

    return trainX, trainY, testX, testY

# %%
X_train, y_train, X_test, y_test = load_cifar10()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 10), (10000, 32, 32, 3), (10000, 10))

# %% [markdown]
# ### Step 1 - Display some images
#
# Display the first 25 images from the train set.

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X_train[i])
    plt.title(class_names[np.where(y_train[i]==1)[0][0]])
    plt.axis("off")

# %% [markdown]
# ### Step 2 - Set up a Convolution layer
#
# Create a Conv2D layer called **Conv** with
# - 32, $3\times3$ kernels
# - `'he_uniform'` kernel initializer
# - Padding
# - ReLu activation

# %%
# Create a Cionv2D model with 32 filters, kernel size of 3x3, and relu activation with padding set to 'same' and ke_uniform initializer
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_uniform', input_shape = (32, 32, 3)))

# %% [markdown]
# ### Step 3 - Set up a Max pooling layer
#
# Create a MaxPooling2D layer with pool_size equal 2, name the single layer **Max**.

# %%
Max = MaxPooling2D(pool_size = (2, 2))

# %% [markdown]
# ### Step 4 - Create a deeper CNN with blocks
#
# Now that we've practiced defining the two types of most commonly used layers in CNN. Let's stack two **Conv** layers and one **Max** layer together as a block, and create a deeper CNN with three of those blocks.
#
# We could choose to double the number of kernels/channels in the **Conv2D** layers as you move from one block to another.

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_uniform', input_shape = (32, 32, 3)))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.summary()
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 896 (3.50 KB)
#  Trainable params: 896 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 5 - Dense Layers

# %% [markdown]
# Let's finish up building your CNN with some Dense layers. I will touch more on Flattening and Dense layers in a follow-up notebook.

# %%
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))
model.summary()
# compile model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 280, 500, 1)    │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 140000)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    17,920,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,921,428 (68.36 MB)
#  Trainable params: 17,921,428 (68.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Conclusion
#
# That concludes this notebook, we built a deeper CNN model using multiple convolutional and pooling layers, followed by dense layers for classification. This sequential model structure is essential for various computer vision tasks, such as image classification, object detection, and image segmentation.
#
# By combining these techniques, we can create powerful CNN models capable of solving complex image processing challenges in real-world applications.

# %% [markdown]
# ### Business Use Cases
# 1. **Image Classification**: CNNs can be used to classify images into different categories, such as identifying objects in photos or diagnosing medical conditions from X-ray images.
# 2. **Object Detection**: Detecting and localizing objects within an image, useful in applications like autonomous driving and security surveillance.
# 3. **Image Segmentation**: Dividing an image into multiple segments to simplify analysis, used in medical imaging to identify different tissue types.
# 4. **Facial Recognition**: Identifying or verifying individuals based on their facial features, used in security systems and user authentication.
# 5. **Visual Search**: Enabling search engines to find similar images based on a query image, used in e-commerce for finding products visually.
# 6. **Augmented Reality**: Overlaying digital information on the real world, used in gaming, retail, and education to enhance user experience.
#
#
# ## Recap of Key Concepts and Functions:
#
# ### Convolutional Neural Networks (CNNs)
# CNNs are a class of deep neural networks that are particularly effective for analyzing visual data. They are composed of several layers, including convolutional layers, pooling layers, and fully connected layers.
#
# ### Padding and Stride
# - **Padding**: Adding extra pixels around the border of an image to control the spatial size of the output. This helps retain information from the border pixels.
# - **Stride**: The number of pixels by which the kernel moves across the image. Larger strides result in smaller output dimensions.
#
# ### Convolutional Layers
# - **Conv2D**: A layer that applies a convolution operation to the input, using a set of learnable filters (kernels). The key parameters include the number of filters, kernel size, padding, strides, and activation function.
#
# ### Activation Functions
# - **ReLU (Rectified Linear Unit)**: An activation function that sets all negative values to zero, introducing non-linearity into the network.
# - **Sigmoid**: An activation function that squashes input values to a range between 0 and 1.
#
# ### Pooling Layers
# - **MaxPooling2D**: A pooling layer that takes the maximum value from each sub-region of the input.
# - **AveragePooling2D**: A pooling layer that takes the average value from each sub-region of the input.
#
# ### Edge Detection
# - **Sobel Operator**: A technique for edge detection using convolution with specific kernels to highlight horizontal and vertical edges.
#
# ### Helper Functions
# - **sobel**: A function that applies the Sobel operator to an image using specified strides and padding.
# - **v_grad and h_grad**: Functions that define custom kernels for vertical and horizontal gradients.
#
# ### Image Processing
# - **PIL (Python Imaging Library)**: Used for opening, manipulating, and saving images.
# - **ImageOps**: A module in PIL for image operations like converting to grayscale.
#
# ### Data Handling
# - **numpy**: A library for numerical operations on arrays.
# - **pandas**: A library for data manipulation and analysis.
# - **matplotlib and seaborn**: Libraries for data visualization.
#
# These concepts and techniques form the foundation for building and deploying powerful image processing and computer vision applications in various industries.
