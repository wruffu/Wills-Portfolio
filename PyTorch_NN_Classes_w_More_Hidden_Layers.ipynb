# %% [markdown]
# # PyTorch NN Classes w/ More Hidden Layers

# %% [markdown]
# ## Objective: Create a more complex neural network in PyTorch.

# %% [markdown]
# ### Steps:
#     Preparation
#     Get Our Data
#     Define the Neural Network, Optimizer and Train the Model

# %% [markdown]
# ## Preparation

# %% [markdown]
# Import the following libraries:

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# Define the plotting functions.

# %%
def get_hist(model,data_set):
    activations=model.activation(data_set.x)
    for i,activation in enumerate(activations):
        plt.hist(activation.numpy(),4,density=True)
        plt.title("Activation layer " + str(i+1))
        plt.xlabel("Activation")
        plt.xlabel("Activation")
        plt.legend()
        plt.show()

# %%
def PlotStuff(X,Y,model=None,leg=False):

    plt.plot(X[Y==0].numpy(),Y[Y==0].numpy(),'or',label='training points y=0 ' )
    plt.plot(X[Y==1].numpy(),Y[Y==1].numpy(),'ob',label='training points y=1 ' )

    if model!=None:
        plt.plot(X.numpy(),model(X).detach().numpy(),label='neral network ')

    plt.legend()
    plt.show()

# %% [markdown]
# ## Get Our Data

# %% [markdown]
# Define the class to get our dataset.

# %%
class Data(Dataset):
    def __init__(self):
        self.x=torch.linspace(-20, 20, 100).view(-1,1)

        self.y=torch.zeros(self.x.shape[0])
        self.y[(self.x[:,0]>-10)& (self.x[:,0]<-5)]=1
        self.y[(self.x[:,0]>5)& (self.x[:,0]<10)]=1
        self.y=self.y.view(-1,1)
        self.len=self.x.shape[0]
    def __getitem__(self,index):

        return self.x[index],self.y[index]
    def __len__(self):
        return self.len

# %% [markdown]
# ## Define the Neural Network, Optimizer and Train the Model

# %% [markdown]
# Define the class and set the activation function for our model.

# %%
class Net(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net,self).__init__()
        self.linear1=nn.Linear(D_in,H)
        self.linear2=nn.Linear(H,D_out)


    def forward(self,x):
        x=torch.sigmoid(self.linear1(x))
        x=torch.sigmoid(self.linear2(x))
        return x

# %% [markdown]
# Create the function to train our model, which accumulate lost for each iteration to obtain the cost.

# %%
def train(data_set,model,criterion, train_loader, optimizer, epochs=5,plot_number=10):
    cost=[]

    for epoch in range(epochs):
        total=0

        for x,y in train_loader:
            optimizer.zero_grad()

            yhat=model(x)
            loss=criterion(yhat,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total+=loss.item()

        if epoch%plot_number==0:
            PlotStuff(data_set.x,data_set.y,model)

        cost.append(total)
    plt.figure()
    plt.plot(cost)
    plt.xlabel('epoch')
    plt.ylabel('cost')
    plt.show()
    return cost

# %%
data_set=Data()

# %%
PlotStuff(data_set.x,data_set.y,leg=False)

# %% [markdown]
# Create our model with 9
# neurons in the hidden layer. And then create a BCE loss and an Adam optimizer.

# %%
torch.manual_seed(0)
model=Net(1,9,1)
learning_rate=0.1
criterion=nn.BCELoss()
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate)
train_loader=DataLoader(dataset=data_set,batch_size=100)
COST=train(data_set,model,criterion, train_loader, optimizer, epochs=600,plot_number=200)

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(1, 6),
    torch.nn.Sigmoid(),
    torch.nn.Linear(6,1),
    torch.nn.Sigmoid()
)

# %%
plt.plot(COST)

# %% [markdown]
# ## Summary
#
# This Jupyter Notebook demonstrates the creation and training of a neural network using PyTorch. The key concepts covered include:
#
# 1. **Preparation**:
#     - Importing necessary libraries such as PyTorch, NumPy, and Matplotlib.
#     - Defining plotting functions to visualize data and model performance.
#
# 2. **Data Preparation**:
#     - Creating a custom dataset class `Data` to generate and manage the input data.
#
# 3. **Model Definition**:
#     - Defining a neural network class `Net` with an input layer, one hidden layer, and an output layer.
#     - Creating a more complex neural network using `torch.nn.Sequential`.
#
# 4. **Training the Model**:
#     - Implementing a training function to train the model using the Binary Cross Entropy (BCE) loss and Adam optimizer.
#     - Visualizing the training process by plotting the cost over epochs.
#
# 5. **Visualization**:
#     - Plotting the dataset and the model's predictions to understand the model's performance.
#
# ### Real World Potential Takeaways
#
# - **Understanding Neural Networks**: This notebook provides a hands-on approach to understanding the structure and training process of neural networks.
# - **Data Handling**: Demonstrates how to create and manage datasets in PyTorch, which is crucial for real-world machine learning tasks.
# - **Model Training**: Highlights the importance of choosing appropriate loss functions and optimizers for training neural networks.
# - **Visualization**: Emphasizes the role of visualizing data and model performance to gain insights and improve models.
#
# Overall, this notebook serves as a practical guide for building and training neural networks, which can be applied to various real-world problems such as classification, regression, and more.
